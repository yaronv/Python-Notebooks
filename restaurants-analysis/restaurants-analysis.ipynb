# %% [markdown]
# # Restaurants in Israel Analysis
# In this notebook I'm going to do an EDA on the restaurants in israel
# <br/><br/>
# **The Data**
# <br/>The data is taken from the national data repository [here](https://data.gov.il/)
# <br/><br/>**Contact Details:**
# <br/>Email: yaronv99@gmail.com
# <br/>Github: https://github.com/yaronv
# <br/>Linkedin: https://www.linkedin.com/in/yaronv/

# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
import pandas as pd
import os
from matplotlib import pylab as plt
from matplotlib import pyplot
import numpy as np

# %% [markdown]
# <br/>Let's start by importing the data and see how it looks like

# %%
rests_df = pd.read_excel('data/rests_israel.xls')
rests_df.head()
# Out:
#       Id                 Name  \
# 0  38423  Manta ray -Tel Aviv
# 1  38426        Humus Eliyaho
# 2  38427                 Teta
# 3  38428      Meshek Barzilay
# 4  38435               Allora
#
#                                     ShortDescription  \
# 0  Region: Tel Aviv & Center, Restaurant / Food T...
# 1  Region: North, Restaurant / Food Type: Arabian...
# 2  Region: North, Restaurant / Food Type: Italian...
# 3  Region: Tel Aviv & Center, Restaurant / Food T...
# 4  Region: Tel Aviv & Center, Restaurant / Food T...
#
#                                      FullDescription  VendorId  \
# 0  <p>Manta Ray serves up creatively prepared Med...       462
# 1  <p>Hummusia, located in the city of Haifa, at ...       462
# 2  <p>"Tata," was established in the heart of the...       462
# 3  <p>organic vegetarian restaurant located in th...       462
# 4  <p>Allora is an Italian restaurant in Tel Aviv...       462
#
# ...

# %% [markdown]
# <br/> Now, let's see what columns do we have

# %%
rests_df.dtypes
# Out:
# Id                                           int64
# Name                                        object
# ShortDescription                            object
# FullDescription                             object
# VendorId                                     int64
# Vendor_Name                                 object
# Product_Url                                 object
# Pic_Url                                     object
# Accessibility                               object
# Address                                     object
# Chef_Restaurant                             object
# Chefs_Name                                  object
# City                                        object
# Email                                       object
# Fax                                         object
# First_Name                                  object
# Kosher                                      object
# Near_To                                     object
# ...
