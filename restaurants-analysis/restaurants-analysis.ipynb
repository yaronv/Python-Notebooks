# %% [markdown]
# # Restaurants in Israel Analysis
# In this notebook I'm going to do an EDA on the restaurants in israel
# <br/><br/>
# **The Data**
# <br/>The data is taken from the national data repository [here](https://data.gov.il/)
# <br/><br/>**Contact Details:**
# <br/>Email: yaronv99@gmail.com
# <br/>Github: https://github.com/yaronv
# <br/>Linkedin: https://www.linkedin.com/in/yaronv/

# %%
import warnings
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
import pandas as pd
import os
from matplotlib import pylab as plt
from matplotlib import pyplot
import numpy as np

# %% [markdown]
# <br/>Let's start by importing the data and see how it looks like

# %%
rests_df = pd.read_excel('data/rests_israel.xls')
rests_df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/ds/python-envs/env3.6/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     351         try:
# --> 352             import xlrd
#     353         except ImportError:
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f7af62c097e5> in <module>
# ----> 1 rests_df = pd.read_excel('data/rests_israel.xls')
#       2 rests_df.head()
#
# /home/ds/python-envs/env3.6/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /home/ds/python-envs/env3.6/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# /home/ds/python-envs/env3.6/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, **kwds)
#     305
#     306     if not isinstance(io, ExcelFile):
# --> 307         io = ExcelFile(io, engine=engine)
#     308
#     309     return io.parse(
#
# /home/ds/python-envs/env3.6/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     352             import xlrd
#     353         except ImportError:
# --> 354             raise ImportError(err_msg)
#     355         else:
#     356             ver = tuple(map(int, xlrd.__VERSION__.split(".")[:2]))
#
# ImportError: Install xlrd >= 0.9.0 for Excel support

# %% [markdown]
# <br/> Now, let's see what columns do we have

# %%
rests_df.dtypes
